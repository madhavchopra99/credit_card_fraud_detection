# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
# loading the data
df = pd.read_csv('data/data.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# ### Data Analysis

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# check for null
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
pd.set_option('display.max_columns',32)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# distribution of legit vs fraudlent
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# #### This Dataset is highly unbalanced
#
# 0 --> Normal Transaction \
# 1 --> Fraudulent Transaction

# %%
# data analysis both transactions
ax = sns.countplot(df,x='Class',)
ax.bar_label(ax.containers[0], fontsize=10)
# plt.savefig('screenshots/comparing_count.png')
plt.show()

# %%
# comparing means for both transaction type
ax = sns.barplot(data=df,x='Class',y='Amount',errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)
# plt.savefig('screenshots/comparing_mean_values.png')
plt.show()

# %%
# comparing mean values for all columns
df.groupby('Class').agg(['mean'])
# Out:
#                Time        V1        V2        V3        V4        V5  \
#                mean      mean      mean      mean      mean      mean
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
#            mean      mean      mean      mean      mean      mean      mean
# Class
# 0      0.002419  0.009637 -0.000987  0.004467  0.009824 -0.006576  0.010832
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
#            mean      mean      mean      mean      mean      mean      mean
# Class
# 0      0.000189  0.012064  0.000161  0.007164  0.011535  0.003887 -0.001178
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
# ...

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and fraudulent transactions

# %% [markdown]
# Number of Fraudulent Transactions -> 492

# %%
legit = df[df['Class'] == 0 ]
fraud = df[df['Class'] ==1]

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# #### concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0,ignore_index=True)

# %%
new_dataset.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  139962.0 -2.301927  2.006963 -0.017366 -1.203718  0.222056  1.368628
# 1   69832.0 -3.300157 -4.565055  0.514195 -1.582879  1.782380 -1.862705
# 2   27955.0 -0.658448 -0.229636  1.969058 -2.034248 -0.630947  0.646010
# 3   18853.0 -0.474559  1.070164  1.477545  0.164367  0.160497 -0.229744
# 4   56565.0 -2.897921  2.835068 -0.647328  0.644691 -1.315769 -0.426822
#
#          V7        V8        V9       V10       V11       V12       V13  \
# 0 -1.121390 -2.670765  0.563269 -0.089831 -0.071075  1.459946  1.082537
# 1 -2.693970  0.713218 -2.343644  0.869787 -0.127528  0.300218  2.149890
# 2 -0.500458  0.518075 -0.827650  0.188135  0.486354 -1.035422 -0.959300
# 3  0.498913  0.128358  0.648028 -0.768644  2.787999 -1.905998  1.329659
# 4 -0.959710  1.902899 -0.400199  0.701583  0.889030  0.728874 -1.132325
#
#         V14       V15       V16       V17       V18       V19       V20  \
# ...

# %%
new_dataset.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9       V10       V11       V12       V13  \
# 979 -0.882850  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123
# 980 -1.413170  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532
# 981 -2.234739  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950
# 982 -2.208002  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455
# 983  0.223050 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').agg(['mean'])
# Out:
#                Time        V1        V2        V3        V4        V5  \
#                mean      mean      mean      mean      mean      mean
# Class
# 0      95408.443089  0.086882  0.027031  0.020656 -0.088568  0.049827
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
#            mean      mean      mean      mean      mean      mean      mean
# Class
# 0      0.016390  0.029393  0.020655 -0.061964  0.025313  0.036420 -0.039215
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
#            mean      mean      mean      mean      mean      mean      mean
# Class
# 0      0.003915  0.015295 -0.007099  0.033687  0.008095  0.018999 -0.004923
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
# ...

# %% [markdown]
# #### Spliting features and targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
y = new_dataset['Class'].to_numpy()

# %%
X.shape
# Out:
# (984, 30)

# %%
y.shape
# Out:
# (984,)

# %% [markdown]
# #### Split Data into Training Data and Test data

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=2)

# %% [markdown]
# ### Model Training

# %%
model = LogisticRegression(solver='newton-cg',max_iter=500)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500, solver='newton-cg')

# %%
# checking for overfitting
model.score(X_train,y_train)
# Out:
# 0.9542566709021602

# %%
# Checking score of testing data
score = model.score(X_test,y_test)
print(score)
# Out:
# 0.9441624365482234

# %%
from sklearn.metrics import confusion_matrix

# %%
test_prediction = model.predict(X_test)

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test,test_prediction)
modified_cm = []
for index,value in enumerate(cm):
    if index == 0:
        modified_cm.append(['TN = ' + str(value[0]), 'FP = ' + str(value[1])])
    if index == 1:
        modified_cm.append(['FN = ' + str(value[0]), 'TP = ' + str(value[1])])

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=np.array(modified_cm),
            fmt="",
            annot_kws={"size": 20},
            linewidths=.5,
            square = True,
            cmap = 'Blues',
            xticklabels = ['Legit', 'Fraud'],
            yticklabels = ['Legit', 'Fraud'],
            );
plt.ylabel('Actual label', fontsize = 17)
plt.xlabel('Predicted label', fontsize = 17)
plt.title(f"Accuracy Score: {score*100:.2f}%", size = 17)
plt.tick_params(labelsize=15)
# plt.savefig('screenshots/confusion matrix.png')
plt.show()
